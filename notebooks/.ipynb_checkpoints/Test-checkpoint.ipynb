# %% [markdown]
# # Welcome to our fancy Jupyter Notebook Presentation
# please navigate with the following keys:
# - *forward:* `space`
# - *backward:* `shit+space`
#
# Excecute code by pressing `alt+enter`

# %%
import numpy as np
import matplotlib.pyplot as plt
import requests

# %% [markdown]
# # Hello Slide No 1

# %% [markdown]
# was ist denn hier los?

# %% [markdown]
# This will be a sub slide

# %% [markdown]
# ### Fancy live coding

# %%
# Lets create some fancy points
rand_points = np.random.standard_normal(500)

# %%
# and then plot them
plt.plot(rand_points)

# %%
requests.get("https://google.de")
# Out:
# <Response [200]>
